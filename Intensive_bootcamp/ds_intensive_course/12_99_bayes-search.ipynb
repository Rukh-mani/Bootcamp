# %% [markdown]
# # Bayesian optimization
# Useful in situations where you don't have an analytical form of the function or its derivatives, and each evaluation of the function (such as training a machine learning model with a particular set of hyperparameters) can be time-consuming or resource-intensive.
#
# **Surrogate Model:** Bayesian optimization builds a probabilistic model, known as the surrogate model, to approximate the objective function. This model, typically a Gaussian Process but can also be a Random Forest or other models, provides a prediction of the objective function's output and an estimate of the uncertainty of this prediction at any given point in the hyperparameter space.
#
# **Acquisition Function:** The algorithm uses an acquisition function to decide where to sample next. The acquisition function balances exploration (sampling where the model is uncertain) and exploitation (sampling where the model predicts high performance). Common acquisition functions include Expected Improvement, Probability of Improvement, and Upper Confidence Bound.
#
#
# Each time the objective function is evaluated (e.g., training a model with a certain hyperparameter set), the result is fed back into the model, updating its understanding of the function. This updated model is then used to determine the next point to evaluate.
#
#
# Bayesian optimization is an iterative process. In each iteration, it uses the current surrogate model to select the most promising point to evaluate next based on the acquisition function. After evaluation, the surrogate model is updated with the new observation. This process continues until a stopping criterion is met (like a maximum number of iterations or a convergence threshold).
#
#
# The key advantage of Bayesian optimization is its efficiency, especially in high-dimensional spaces or when each evaluation of the objective function is costly (like in hyperparameter tuning of complex machine learning models). It requires fewer evaluations of the objective function compared to other methods like grid search or random search.
#
#
# The primary limitation of Bayesian optimization is the complexity of the surrogate model, especially for high-dimensional hyperparameter spaces. Also, the performance can heavily depend on the choice of the surrogate model and the acquisition function.

# %%
import optuna
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Load the Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Define the objective function to be optimized
def objective(trial):
    # Define the hyperparameter search space using Optuna
    n_estimators = trial.suggest_int("n_estimators", 10, 200)
    max_depth = trial.suggest_int("max_depth", 1, 32)
    min_samples_split = trial.suggest_float("min_samples_split", 0.1, 1)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 4)
    max_features = trial.suggest_categorical("max_features", ["sqrt", "log2"])

    # Initialize and train the RandomForestClassifier
    clf = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
    )
    # Perform cross-validation and return the mean accuracy
    return cross_val_score(clf, X, y, n_jobs=-1, cv=3).mean()

# Create a study object and specify the optimization direction
study = optuna.create_study(direction="maximize")
# Perform the optimization
study.optimize(objective, n_trials=100)

# Best parameters and score
best_params = study.best_params
best_score = study.best_value

best_params, best_score
# Out:
# [I 2023-11-14 12:44:52,562] A new study created in memory with name: no-name-007e38e4-a3d9-4197-8e19-4f043b5774c0
# [I 2023-11-14 12:44:54,813] Trial 0 finished with value: 0.32666666666666666 and parameters: {'n_estimators': 50, 'max_depth': 28, 'min_samples_split': 0.8222671658601485, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.32666666666666666.
# [I 2023-11-14 12:44:55,756] Trial 1 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 93, 'max_depth': 28, 'min_samples_split': 0.2545242559478056, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.9466666666666667.
# [I 2023-11-14 12:44:56,102] Trial 2 finished with value: 0.3333333333333333 and parameters: {'n_estimators': 104, 'max_depth': 5, 'min_samples_split': 0.9185716659147138, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.9466666666666667.
# [I 2023-11-14 12:44:56,369] Trial 3 finished with value: 0.32 and parameters: {'n_estimators': 79, 'max_depth': 15, 'min_samples_split': 0.7249146343207472, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.9466666666666667.
# [I 2023-11-14 12:44:56,711] Trial 4 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 109, 'max_depth': 7, 'min_samples_split': 0.5827923242680573, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 1 with value: 0.9466666666666667.
# [I 2023-11-14 12:44:56,868] Trial 5 finished with value: 0.32666666666666666 and parameters: {'n_estimators': 41, 'max_depth': 24, 'min_samples_split': 0.9586964026441628, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 1 with value: 0.9466666666666667.
# [I 2023-11-14 12:44:57,069] Trial 6 finished with value: 0.9133333333333334 and parameters: {'n_estimators': 59, 'max_depth': 11, 'min_samples_split': 0.5935128994068565, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.9466666666666667.
# [I 2023-11-14 12:44:57,471] Trial 7 finished with value: 0.96 and parameters: {'n_estimators': 139, 'max_depth': 17, 'min_samples_split': 0.4792700724983828, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 7 with value: 0.96.
# [I 2023-11-14 12:44:57,723] Trial 8 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 76, 'max_depth': 2, 'min_samples_split': 0.505495172874298, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 7 with value: 0.96.
# [I 2023-11-14 12:44:57,904] Trial 9 finished with value: 0.32666666666666666 and parameters: {'n_estimators': 47, 'max_depth': 16, 'min_samples_split': 0.8641796709156936, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 7 with value: 0.96.
# [I 2023-11-14 12:44:58,396] Trial 10 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 167, 'max_depth': 21, 'min_samples_split': 0.15203608771251426, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:44:58,944] Trial 11 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 165, 'max_depth': 22, 'min_samples_split': 0.11418701959662474, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:44:59,644] Trial 12 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 196, 'max_depth': 22, 'min_samples_split': 0.15057809325337607, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:00,195] Trial 13 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 171, 'max_depth': 22, 'min_samples_split': 0.1109272235144633, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:00,658] Trial 14 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 146, 'max_depth': 31, 'min_samples_split': 0.29550190685834815, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:01,268] Trial 15 finished with value: 0.94 and parameters: {'n_estimators': 192, 'max_depth': 19, 'min_samples_split': 0.2886389197405371, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:01,724] Trial 16 finished with value: 0.96 and parameters: {'n_estimators': 148, 'max_depth': 25, 'min_samples_split': 0.10396864947357565, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:02,229] Trial 17 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 168, 'max_depth': 11, 'min_samples_split': 0.39399552567525253, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:02,610] Trial 18 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 121, 'max_depth': 20, 'min_samples_split': 0.22651033819635152, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:02,705] Trial 19 finished with value: 0.96 and parameters: {'n_estimators': 11, 'max_depth': 13, 'min_samples_split': 0.1896262491697296, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:03,223] Trial 20 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 171, 'max_depth': 26, 'min_samples_split': 0.36240986059950364, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:03,823] Trial 21 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 197, 'max_depth': 21, 'min_samples_split': 0.15330116255007956, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:04,357] Trial 22 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 178, 'max_depth': 23, 'min_samples_split': 0.17321872206098665, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:04,832] Trial 23 finished with value: 0.96 and parameters: {'n_estimators': 157, 'max_depth': 32, 'min_samples_split': 0.20736123558684996, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:05,225] Trial 24 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 130, 'max_depth': 20, 'min_samples_split': 0.10502440864367307, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:05,890] Trial 25 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 186, 'max_depth': 18, 'min_samples_split': 0.3421941431939481, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:06,481] Trial 26 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 200, 'max_depth': 27, 'min_samples_split': 0.23749541553752684, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:06,979] Trial 27 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 156, 'max_depth': 14, 'min_samples_split': 0.17356242669066418, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:07,516] Trial 28 finished with value: 0.94 and parameters: {'n_estimators': 183, 'max_depth': 30, 'min_samples_split': 0.29231275213953783, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:08,006] Trial 29 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 164, 'max_depth': 23, 'min_samples_split': 0.1447261036307238, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:08,384] Trial 30 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 130, 'max_depth': 25, 'min_samples_split': 0.4136898102523956, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:09,097] Trial 31 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 176, 'max_depth': 22, 'min_samples_split': 0.12574281119845693, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:09,557] Trial 32 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 157, 'max_depth': 29, 'min_samples_split': 0.2353969591212636, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:10,073] Trial 33 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 180, 'max_depth': 22, 'min_samples_split': 0.10687367789904538, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:10,617] Trial 34 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 190, 'max_depth': 18, 'min_samples_split': 0.17108720216680112, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:10,995] Trial 35 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 112, 'max_depth': 27, 'min_samples_split': 0.24202955745584276, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:11,463] Trial 36 finished with value: 0.96 and parameters: {'n_estimators': 164, 'max_depth': 21, 'min_samples_split': 0.19646608642848035, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:11,885] Trial 37 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 143, 'max_depth': 24, 'min_samples_split': 0.1496672391319896, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:12,185] Trial 38 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 99, 'max_depth': 16, 'min_samples_split': 0.28582025186624865, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:12,611] Trial 39 finished with value: 0.96 and parameters: {'n_estimators': 135, 'max_depth': 28, 'min_samples_split': 0.10433766480880123, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:12,897] Trial 40 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 90, 'max_depth': 19, 'min_samples_split': 0.21035303066312355, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:13,455] Trial 41 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 198, 'max_depth': 21, 'min_samples_split': 0.1536235657902641, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:14,162] Trial 42 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 191, 'max_depth': 23, 'min_samples_split': 0.1492891532031733, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:14,767] Trial 43 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 200, 'max_depth': 21, 'min_samples_split': 0.24754851515584125, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:15,261] Trial 44 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 172, 'max_depth': 17, 'min_samples_split': 0.14464685327422525, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:15,692] Trial 45 finished with value: 0.96 and parameters: {'n_estimators': 151, 'max_depth': 24, 'min_samples_split': 0.19841225949522345, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:16,224] Trial 46 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 186, 'max_depth': 19, 'min_samples_split': 0.2686324282938831, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:16,741] Trial 47 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 163, 'max_depth': 26, 'min_samples_split': 0.10050707855583474, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:17,259] Trial 48 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 179, 'max_depth': 8, 'min_samples_split': 0.3398400569302286, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:17,807] Trial 49 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 193, 'max_depth': 15, 'min_samples_split': 0.18838702048293818, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.9666666666666667.
# [I 2023-11-14 12:45:18,027] Trial 50 finished with value: 0.9733333333333333 and parameters: {'n_estimators': 64, 'max_depth': 20, 'min_samples_split': 0.1425687516993196, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:18,242] Trial 51 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 65, 'max_depth': 20, 'min_samples_split': 0.13696950337581226, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:18,510] Trial 52 finished with value: 0.96 and parameters: {'n_estimators': 85, 'max_depth': 22, 'min_samples_split': 0.17744790574544134, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:18,672] Trial 53 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 40, 'max_depth': 17, 'min_samples_split': 0.2210506037114019, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:18,764] Trial 54 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 12, 'max_depth': 25, 'min_samples_split': 0.12838789146558469, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:18,955] Trial 55 finished with value: 0.9266666666666667 and parameters: {'n_estimators': 53, 'max_depth': 1, 'min_samples_split': 0.21235138838814605, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:19,064] Trial 56 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 20, 'max_depth': 19, 'min_samples_split': 0.2626542163544163, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:19,214] Trial 57 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 34, 'max_depth': 23, 'min_samples_split': 0.15904658518735273, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:19,467] Trial 58 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 74, 'max_depth': 21, 'min_samples_split': 0.3217797776596729, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:19,964] Trial 59 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 172, 'max_depth': 20, 'min_samples_split': 0.12752859799835134, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:20,317] Trial 60 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 116, 'max_depth': 18, 'min_samples_split': 0.17353815012610377, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:20,840] Trial 61 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 180, 'max_depth': 24, 'min_samples_split': 0.1846981422511168, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:21,389] Trial 62 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 194, 'max_depth': 23, 'min_samples_split': 0.12593565721852404, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:21,908] Trial 63 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 184, 'max_depth': 22, 'min_samples_split': 0.22254567767890493, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:22,396] Trial 64 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 174, 'max_depth': 25, 'min_samples_split': 0.10206153208762764, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:22,877] Trial 65 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 167, 'max_depth': 20, 'min_samples_split': 0.25581666510501067, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:23,397] Trial 66 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 188, 'max_depth': 26, 'min_samples_split': 0.1656524270683905, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:23,825] Trial 67 finished with value: 0.96 and parameters: {'n_estimators': 148, 'max_depth': 22, 'min_samples_split': 0.20627416689495287, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:24,259] Trial 68 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 157, 'max_depth': 18, 'min_samples_split': 0.12902524478635313, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:24,582] Trial 69 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 103, 'max_depth': 23, 'min_samples_split': 0.17119450412156711, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:25,039] Trial 70 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 162, 'max_depth': 21, 'min_samples_split': 0.23995653874601747, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:25,408] Trial 71 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 126, 'max_depth': 20, 'min_samples_split': 0.10343629625184392, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:25,907] Trial 72 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 177, 'max_depth': 22, 'min_samples_split': 0.14211515002789635, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:26,320] Trial 73 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 139, 'max_depth': 19, 'min_samples_split': 0.19170464879224, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:26,756] Trial 74 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 153, 'max_depth': 24, 'min_samples_split': 0.15615522876738233, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:27,309] Trial 75 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 195, 'max_depth': 15, 'min_samples_split': 0.12413021219775577, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:27,845] Trial 76 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 183, 'max_depth': 21, 'min_samples_split': 0.2222498822773649, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:28,348] Trial 77 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 168, 'max_depth': 27, 'min_samples_split': 0.16491137770737524, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:28,917] Trial 78 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 200, 'max_depth': 24, 'min_samples_split': 0.12058107200600007, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:29,324] Trial 79 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 142, 'max_depth': 20, 'min_samples_split': 0.10028005499855167, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:29,846] Trial 80 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 190, 'max_depth': 17, 'min_samples_split': 0.19863264832272523, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:30,304] Trial 81 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 161, 'max_depth': 12, 'min_samples_split': 0.1480745026654697, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:30,695] Trial 82 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 132, 'max_depth': 13, 'min_samples_split': 0.17951648194761924, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:31,289] Trial 83 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 158, 'max_depth': 14, 'min_samples_split': 0.15406747234506865, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:31,767] Trial 84 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 168, 'max_depth': 9, 'min_samples_split': 0.11696537756056533, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:32,208] Trial 85 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 153, 'max_depth': 16, 'min_samples_split': 0.2804462540920974, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:32,709] Trial 86 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 178, 'max_depth': 4, 'min_samples_split': 0.13722332615755206, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:33,075] Trial 87 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 125, 'max_depth': 23, 'min_samples_split': 0.23045342309907074, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:33,572] Trial 88 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 174, 'max_depth': 18, 'min_samples_split': 0.19025286617725745, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:34,105] Trial 89 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 184, 'max_depth': 19, 'min_samples_split': 0.20774720245366865, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:34,524] Trial 90 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 146, 'max_depth': 21, 'min_samples_split': 0.16438648255338625, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:34,990] Trial 91 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 166, 'max_depth': 23, 'min_samples_split': 0.13963023275231043, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:35,474] Trial 92 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 171, 'max_depth': 22, 'min_samples_split': 0.17651814216450593, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:35,938] Trial 93 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 159, 'max_depth': 25, 'min_samples_split': 0.12065493752327344, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:36,462] Trial 94 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 188, 'max_depth': 24, 'min_samples_split': 0.1454590109911647, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:37,000] Trial 95 finished with value: 0.9466666666666667 and parameters: {'n_estimators': 196, 'max_depth': 26, 'min_samples_split': 0.25569123810545064, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:37,519] Trial 96 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 180, 'max_depth': 20, 'min_samples_split': 0.11433363508113084, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:37,962] Trial 97 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 153, 'max_depth': 22, 'min_samples_split': 0.19012967201388203, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:38,324] Trial 98 finished with value: 0.9533333333333333 and parameters: {'n_estimators': 116, 'max_depth': 23, 'min_samples_split': 0.10028275228613212, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# [I 2023-11-14 12:45:38,566] Trial 99 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 71, 'max_depth': 21, 'min_samples_split': 0.1615972331791388, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 50 with value: 0.9733333333333333.
# ({'n_estimators': 64,
#   'max_depth': 20,
#   'min_samples_split': 0.1425687516993196,
#   'min_samples_leaf': 3,
#   'max_features': 'log2'},
#  0.9733333333333333)

# %%
best_params
# Out:
# {'n_estimators': 64,
#  'max_depth': 20,
#  'min_samples_split': 0.1425687516993196,
#  'min_samples_leaf': 3,
#  'max_features': 'log2'}

# %%
rf = RandomForestClassifier(
        n_estimators = best_params["n_estimators"],
        max_depth=best_params["max_depth"],
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
)
pipeline = Pipeline([
    (Scaler),
    (rf)
])
pipeline.fit(X,y)
