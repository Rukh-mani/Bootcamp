# %%
import pandas as pd
import numpy as np

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link_csv = 'https://drive.google.com/file/d/1JXzggzlT20uYxdE7wmMrslpp9R6GD-Qw/view'
link_excel = 'https://drive.google.com/file/d/1G4xJO9cfiOZFkh17szJiwsXqKroV4hKh/view'

import pandas as pd

# to get the id part of the file
id = link_csv.split("/")[-2]

downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('googleplaystore.csv')
df = pd.read_csv('googleplaystore.csv')
print(df)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %% [markdown]
# # Reading files (.csv, .xlsx)

# %%
# Read a CSV file into a DataFrame
#df = pd.read_csv("data/googleplaystore.csv")

# Let's take a look what "df" is
# Notice, how you can combine f-strings and python variables
# Finished early? Take a few minutes to expore f-strings in detail! https://www.datacamp.com/tutorial/f-string-formatting-in-python?
print(f"Pandas library saved data into {type(df)} type of object.")
print("\n")

# Display the first 5 rows of the DataFrame
df.head()
# Out:
# Pandas library saved data into <class 'pandas.core.frame.DataFrame'> type of object.
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
# 6     178   19M      50,000+  Free     0       Everyone
# 7   36815   29M   1,000,000+  Free     0       Everyone
# 8   13791   33M   1,000,000+  Free     0       Everyone
# 9     121  3.1M      10,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                 1.0
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %%
id = link_excel.split("/")[-2]
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('googleplaystore.xlsx')
df2 = pd.read_excel("googleplaystore.xlsx")
#TODO list first 20 rows!

# %%
df2 = pd.read_excel("googleplaystore.xlsx", sheet_name = 1)

# %%
df2.head(20)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# 11            Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN     4.4
# 12                     Tattoo Name On My Photo Editor  ART_AND_DESIGN     4.2
# 13                              Mandala Coloring Book  ART_AND_DESIGN     4.6
# 14    3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN     4.4
# 15                    Learn To Draw Kawaii Characters  ART_AND_DESIGN     3.2
# 16       Photo Designer - Write your name with shapes  ART_AND_DESIGN     4.7
# 17                           350 Diy Room Decor Ideas  ART_AND_DESIGN     4.5
# 18                      FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3
# 19                                       ibis Paint X  ART_AND_DESIGN     4.6
#
#      Reviews  Size     Installs  Type  Price Content Rating  \
# 0      159.0   19M      10,000+  Free    0.0       Everyone
# 1      967.0   14M     500,000+  Free    0.0       Everyone
# 2    87510.0  8.7M   5,000,000+  Free    0.0       Everyone
# 3   215644.0   25M  50,000,000+  Free    0.0           Teen
# 4      967.0  2.8M     100,000+  Free    0.0       Everyone
# 5      167.0  5.6M      50,000+  Free    0.0       Everyone
# 6      178.0   19M      50,000+  Free    0.0       Everyone
# 7    36815.0   29M   1,000,000+  Free    0.0       Everyone
# 8    13791.0   33M   1,000,000+  Free    0.0       Everyone
# 9      121.0  3.1M      10,000+  Free    0.0       Everyone
# 10   13880.0   28M   1,000,000+  Free    0.0       Everyone
# 11    8788.0   12M   1,000,000+  Free    0.0       Everyone
# 12   44829.0   20M  10,000,000+  Free    0.0           Teen
# 13    4326.0   21M     100,000+  Free    0.0       Everyone
# 14    1518.0   37M     100,000+  Free    0.0       Everyone
# 15      55.0  2.7M       5,000+  Free    0.0       Everyone
# 16    3632.0  5.5M     500,000+  Free    0.0       Everyone
# 17      27.0   17M      10,000+  Free    0.0       Everyone
# 18  194216.0   39M   5,000,000+  Free    0.0       Everyone
# 19  224399.0   31M  10,000,000+  Free    0.0       Everyone
#
#                        Genres  Last Updated         Current Ver   Android Ver
# 0                Art & Design       43107.0               1.0.0  4.0.3 and up
# 1   Art & Design;Pretend Play       43115.0               2.0.0  4.0.3 and up
# 2                Art & Design       43313.0               1.2.4  4.0.3 and up
# 3                Art & Design       43259.0  Varies with device    4.2 and up
# 4     Art & Design;Creativity       43271.0                 1.1    4.4 and up
# 5                Art & Design       42820.0                 1.0    2.3 and up
# 6                Art & Design       43216.0                 1.1  4.0.3 and up
# 7                Art & Design       43265.0            6.1.61.1    4.2 and up
# 8                Art & Design       42998.0               2.9.2    3.0 and up
# 9     Art & Design;Creativity       43284.0                 2.8  4.0.3 and up
# 10               Art & Design       43035.0               1.0.4    4.1 and up
# 11               Art & Design       43312.0              1.0.15    4.0 and up
# 12               Art & Design       43192.0                 3.8    4.1 and up
# 13               Art & Design       43277.0               1.0.4    4.4 and up
# 14               Art & Design       43315.0               1.2.3    2.3 and up
# 15               Art & Design       43257.0                 NaN    4.2 and up
# 16               Art & Design       43312.0                 3.1    4.1 and up
# 17               Art & Design       43046.0                 1.0    2.3 and up
# 18               Art & Design       43315.0               2.2.5  4.0.3 and up
# 19               Art & Design       43311.0               5.5.4    4.1 and up

# %% [markdown]
# # Basic DataFrame Exploration:

# %%
#View the last few rows of a DataFrame.
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
#TODO Use .info() fuction to get information about the DataFrame, including data types and missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#Generate summary statistics for numerical columns.
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#Get the number of rows and columns in the DataFrame.
df.shape
# Out:
# (10841, 13)

# %%
#TODO use .columns attribute to access column names of the DataFrame.

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#Access the row labels of the DataFrame.
df.index
# Out:
# RangeIndex(start=0, stop=10841, step=1)

# %%
#Access the row label values of the DataFrame.
df.index.values
# Out:
# array([    0,     1,     2, ..., 10838, 10839, 10840])

# %%
#show random sample oof df using .sample() function

# %%
df.sample(frac = .1).head()
# Out:
#                                                      App             Category  \
# 9457                            Rope Superhero Unlimited                 GAME
# 6581   BPme - Mobile Fuel Payment & BP Driver Rewards...     TRAVEL_AND_LOCAL
# 1306       Fabulous: Motivate Me! Meditate, Relax, Sleep   HEALTH_AND_FITNESS
# 6399                              Of the wall Arapaho bk        COMMUNICATION
# 4753       Control Center iOS 11 - Phone X Control Panel                TOOLS
# 4134                       Norwegian For Kids & Babies F               FAMILY
# 2811           Face Filter, Selfie Editor - Sweet Camera          PHOTOGRAPHY
# 5648                           Five Nights at Freddy's 3                 GAME
# 7438                           Codes for GTA San Andreas               FAMILY
# 445                        True Contact - Real Caller ID        COMMUNICATION
# 2216                      Duolingo: Learn Languages Free               FAMILY
# 3020   CBS Sports App - Scores, News, Stats & Watch Live               SPORTS
# 8361                                           DG Coupon             SHOPPING
# 3795                        Newsroom: News Worth Sharing   NEWS_AND_MAGAZINES
# 1965                                     Quiz: Logo game                 GAME
# 9459                                          EJ Ecuador            LIFESTYLE
# 4313                        Discovery K!ds Play! Español               FAMILY
# 10097                     EY EMEIA Diversity & Inclusion             BUSINESS
# 385                                      Viber Messenger        COMMUNICATION
# 3008       Hole19: Golf GPS App, Rangefinder & Scorecard               SPORTS
# 6801      BT Position Sender - Bluetooth Position Sender                TOOLS
# 9793                                    ES File Explorer                TOOLS
# 7136                                             CB News               FAMILY
# 7904                              Tech CU Mobile Banking              FINANCE
# 6991   Adult Color By Number Book: Number Coloring Pages               FAMILY
# 5992                                PPCNP-BC Pocket Prep              MEDICAL
# 3292                                          Flashlight                TOOLS
# 5193                          Robin - AI Voice Assistant  MAPS_AND_NAVIGATION
# 2519           Airway Ex - Intubate. Anesthetize. Train.              MEDICAL
# 282                            join.me - Simple Meetings             BUSINESS
# 3640                          Real time Weather Forecast              WEATHER
# 2064             Papumba Academy - Fun Learning For Kids               FAMILY
# 1627                                                Zara            LIFESTYLE
# 2487                                  Anthem BC Anywhere              MEDICAL
# 5685                  Jobs in Canada - Emplois au Canada             BUSINESS
# 9651                                           EO RAIPUR               SOCIAL
# 2884                                       Google Photos          PHOTOGRAPHY
# 4894                                  Chatime AB Rewards               FAMILY
# 3343                     CM Locker - Security Lockscreen                TOOLS
# 4155                                          G-Switch 3                 GAME
#
#        Rating   Reviews                Size        Installs  Type   Price  \
# 9457      4.4      6735                 26M      1,000,000+  Free       0
# 6581      3.0        69                 31M         10,000+  Free       0
# 1306      4.6    205299                 31M      5,000,000+  Free       0
# 6399      NaN         0                 12M              5+  Free       0
# 4753      4.1      1925                8.3M        100,000+  Free       0
# 4134      NaN         0                 14M              5+  Paid  $39.99
# 2811      4.7    142634                 22M     10,000,000+  Free       0
# 5648      4.7     27856                 50M        100,000+  Paid   $2.99
# 7438      3.8     12414                 13M      1,000,000+  Free       0
# 445       4.1     32283  Varies with device      1,000,000+  Free       0
# 2216      4.7   6294397  Varies with device    100,000,000+  Free       0
# 3020      4.3     91031  Varies with device      5,000,000+  Free       0
# 8361      3.7       668                1.1M        100,000+  Free       0
# 3795      4.2    201737  Varies with device     10,000,000+  Free       0
# 1965      4.5    306764                 29M     10,000,000+  Free       0
# 9459      NaN         9                6.8M            100+  Free       0
# 4313      4.2     11263                 35M      1,000,000+  Free       0
# 10097     NaN         4                 12M            500+  Free       0
# 385       4.3  11334973  Varies with device    500,000,000+  Free       0
# 3008      4.4      6106  Varies with device        100,000+  Free       0
# 6801      NaN         0                2.9M             10+  Free       0
# 9793      4.1       278                2.8M        100,000+  Free       0
# 7136      5.0         7                 20M             50+  Free       0
# 7904      4.5       853                 27M         10,000+  Free       0
# 6991      4.2      2231                 37M        500,000+  Free       0
# 5992      NaN         3                 12M             50+  Free       0
# 3292      4.7    115409  Varies with device     10,000,000+  Free       0
# 5193      4.2     55313                 16M      1,000,000+  Free       0
# 2519      4.3       123                 86M         10,000+  Free       0
# 282       4.0      6989  Varies with device      1,000,000+  Free       0
# 3640      4.4      4184                 10M      1,000,000+  Free       0
# 2064      4.4       496                 94M        100,000+  Free       0
# 1627      4.3     95904                 33M     10,000,000+  Free       0
# 2487      2.6       496                 24M        100,000+  Free       0
# 5685      5.0         2                 14M          1,000+  Free       0
# 9651      NaN         1                4.2M             10+  Free       0
# 2884      4.5  10859051  Varies with device  1,000,000,000+  Free       0
# 4894      NaN         9                 22M          1,000+  Free       0
# 3343      4.6   3090727  Varies with device    100,000,000+  Free       0
# 4155      4.6      3656                 39M        100,000+  Free       0
#
#       Content Rating                       Genres        Last Updated  \
# 9457      Mature 17+                       Action        May 10, 2017
# 6581        Everyone               Travel & Local       June 11, 2018
# 1306        Everyone             Health & Fitness       July 16, 2018
# 6399        Everyone                Communication     August 18, 2017
# 4753        Everyone                        Tools   November 15, 2017
# 4134        Everyone                    Education  September 24, 2015
# 2811        Everyone                  Photography        July 6, 2018
# 5648            Teen                       Action       April 2, 2015
# 7438        Everyone                Entertainment      August 4, 2017
# 445         Everyone                Communication       July 26, 2018
# 2216        Everyone          Education;Education      August 1, 2018
# 3020        Everyone                       Sports      August 4, 2018
# 8361        Everyone                     Shopping       July 16, 2018
# 3795    Everyone 10+             News & Magazines        July 3, 2018
# 1965        Everyone                       Trivia      August 3, 2018
# 9459            Teen                    Lifestyle   November 22, 2016
# 4313        Everyone  Entertainment;Music & Video         May 3, 2018
# 10097       Everyone                     Business   November 25, 2016
# 385         Everyone                Communication       July 18, 2018
# 3008        Everyone                       Sports      August 1, 2018
# 6801        Everyone                        Tools        July 3, 2018
# 9793        Everyone                        Tools        July 2, 2018
# 7136        Everyone                    Education  September 10, 2016
# 7904        Everyone                      Finance       July 12, 2018
# 6991        Everyone                Entertainment       July 23, 2018
# 5992        Everyone                      Medical       July 12, 2018
# 3292        Everyone                        Tools      August 6, 2018
# 5193        Everyone            Maps & Navigation      August 5, 2018
# 2519        Everyone                      Medical        June 1, 2018
# 282         Everyone                     Business       July 16, 2018
# 3640        Everyone                      Weather      March 26, 2018
# 2064        Everyone          Education;Education       July 11, 2018
# 1627        Everyone                    Lifestyle       July 30, 2018
# 2487        Everyone                      Medical       July 27, 2018
# 5685            Teen                     Business      August 5, 2018
# 9651            Teen                       Social       June 21, 2017
# 2884        Everyone                  Photography      August 6, 2018
# 4894        Everyone                Entertainment       June 22, 2018
# 3343        Everyone                        Tools       July 31, 2018
# 4155        Everyone                       Action      March 15, 2018
#
#               Current Ver         Android Ver
# 9457                  1.1          2.3 and up
# 6581                3.4.1          5.0 and up
# 1306                 3.48          4.1 and up
# 6399                  1.0          4.1 and up
# 4753                  3.1          4.4 and up
# 4134                  1.0          4.0 and up
# 2811                1.5.1          4.4 and up
# 5648                 1.07          2.3 and up
# 7438                1.0.0          4.1 and up
# 445    Varies with device  Varies with device
# 2216   Varies with device  Varies with device
# 3020   Varies with device          5.0 and up
# 8361                 20.0          4.0 and up
# 3795   Varies with device  Varies with device
# 1965                  6.2        4.0.3 and up
# 9459               3.0.16          4.0 and up
# 4313           2.1.0.2173        4.0.3 and up
# 10097               1.0.0          4.4 and up
# 385    Varies with device  Varies with device
# 3008   Varies with device  Varies with device
# 6801                1.2.0          4.4 and up
# 9793                3.1.5          4.0 and up
# 7136                1.2.0          4.1 and up
# 7904              4.13.72          4.1 and up
# 6991                  2.9          4.4 and up
# 5992                4.5.2          4.4 and up
# 3292   Varies with device  Varies with device
# 5193                4.435          4.1 and up
# 2519               0.6.88          5.0 and up
# 282             4.3.0.508          4.4 and up
# 3640            7.1.12.12          5.0 and up
# 2064                  1.0          4.2 and up
# 1627                4.1.0          4.1 and up
# 2487              8.0.226          4.4 and up
# 5685                  1.1          4.2 and up
# 9651                  1.0        4.0.3 and up
# 2884   Varies with device  Varies with device
# 4894             2.7.0621          4.2 and up
# 3343   Varies with device  Varies with device
# 4155                1.1.3          3.0 and up

# %%
#access column
print(type(df["Genres"]))
df["Genres"]
# Out:
# <class 'pandas.core.series.Series'>
# 0                     Art & Design
# 1        Art & Design;Pretend Play
# 2                     Art & Design
# 3                     Art & Design
# 4          Art & Design;Creativity
#                    ...
# 10836                    Education
# 10837                    Education
# 10838                      Medical
# 10839            Books & Reference
# 10840                    Lifestyle
# Name: Genres, Length: 10841, dtype: object

# %%
#or same result differenty syntax
df.Genres
# Out:
# 0                     Art & Design
# 1        Art & Design;Pretend Play
# 2                     Art & Design
# 3                     Art & Design
# 4          Art & Design;Creativity
#                    ...
# 10836                    Education
# 10837                    Education
# 10838                      Medical
# 10839            Books & Reference
# 10840                    Lifestyle
# Name: Genres, Length: 10841, dtype: object

# %%
#access a row with index = 4
df.iloc[4]
# Out:
# App               Pixel Draw - Number Art Coloring Book
# Category                                 ART_AND_DESIGN
# Rating                                              4.3
# Reviews                                             967
# Size                                               2.8M
# Installs                                       100,000+
# Type                                               Free
# Price                                                 0
# Content Rating                                 Everyone
# Genres                          Art & Design;Creativity
# Last Updated                              June 20, 2018
# Current Ver                                         1.1
# Android Ver                                  4.4 and up
# Name: 4, dtype: object

# %%
#TODO access Column Price from a row with index = 10

# %%
df["Price"][10]
# Out:
# '0'

# %%
df.iloc[10]["Price"]
# Out:
# '0'

# %%
#Column Generes is pandas Series object
print(type(df.Genres))
# Out:
# <class 'pandas.core.series.Series'>

# %%
list(df.Genres)
# Out:
# ['Art & Design',
#  'Art & Design;Pretend Play',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Creativity',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Creativity',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Action & Adventure',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Creativity',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Creativity',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Creativity',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics;Creativity',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Creativity',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Creativity',
#  'Education;Education',
#  'Education',
#  'Education;Music & Video',
#  'Education;Education',
#  'Education;Creativity',
#  'Education',
#  'Education',
#  'Education;Action & Adventure',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Pretend Play',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Brain Games',
#  'Education',
#  'Education;Brain Games',
#  'Education;Brain Games',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education;Pretend Play',
#  'Education;Education',
#  'Education;Pretend Play',
#  'Education;Pretend Play',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Brain Games',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Brain Games',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Creativity',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  ...]

# %%
#however you can transform it e.g. to list with to_list() python method
df.Genres.to_list()
# Out:
# ['Art & Design',
#  'Art & Design;Pretend Play',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Creativity',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Creativity',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Action & Adventure',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Creativity',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Creativity',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design;Creativity',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Art & Design',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Auto & Vehicles',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Beauty',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Books & Reference',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Business',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics;Creativity',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Comics',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Communication',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Dating',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Creativity',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Creativity',
#  'Education;Education',
#  'Education',
#  'Education;Music & Video',
#  'Education;Education',
#  'Education;Creativity',
#  'Education',
#  'Education',
#  'Education;Action & Adventure',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Pretend Play',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Brain Games',
#  'Education',
#  'Education;Brain Games',
#  'Education;Brain Games',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education;Education',
#  'Education',
#  'Education;Pretend Play',
#  'Education;Education',
#  'Education;Pretend Play',
#  'Education;Pretend Play',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Brain Games',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Brain Games',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Creativity',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment;Music & Video',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  ...]

# %%
#or we can use numpy array output
df.Genres.values
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play', 'Art & Design', ...,
#        'Medical', 'Books & Reference', 'Lifestyle'], dtype=object)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
my_list = [1,1,2]
set(my_list)
# Out:
# {1, 2}

# %%
#let's see how many unique Genres there are in the df
# brute force approach using basic python knowledge would allow us to do

genre_list = df.Genres.to_list()
genre_set = set(genre_list) #gives only unique values
print(genre_set)
print(f"There are {len(genre_set)} unique genres in the dataframe")
# Out:
# {'House & Home', 'Educational;Action & Adventure', 'Adventure', 'Auto & Vehicles', 'Simulation;Action & Adventure', 'Art & Design;Creativity', 'Travel & Local;Action & Adventure', 'Educational;Brain Games', 'Books & Reference;Creativity', 'Casual;Pretend Play', 'Social', 'Educational;Creativity', 'Board;Brain Games', 'Maps & Navigation', 'Action;Action & Adventure', 'Libraries & Demo', 'Racing;Pretend Play', 'Strategy;Action & Adventure', 'Arcade', 'Weather', 'Racing;Action & Adventure', 'Simulation;Pretend Play', 'Puzzle;Action & Adventure', 'Card', 'Board;Action & Adventure', 'Video Players & Editors;Music & Video', 'Education;Music & Video', 'Action', 'Puzzle;Education', 'Education;Brain Games', 'Books & Reference', 'Parenting;Education', 'Board', 'Education', 'Simulation;Education', 'Beauty', 'Parenting', 'Art & Design;Pretend Play', 'Casual;Brain Games', 'Entertainment;Education', 'Role Playing;Action & Adventure', 'Puzzle;Creativity', 'Strategy;Creativity', 'Health & Fitness', 'Simulation', 'Adventure;Education', 'Entertainment', 'Education;Creativity', 'Video Players & Editors', 'Education;Pretend Play', 'Role Playing;Brain Games', 'Education;Education', 'Music & Audio;Music & Video', 'Travel & Local', 'Adventure;Brain Games', 'Entertainment;Creativity', 'Medical', 'Role Playing;Pretend Play', 'Art & Design', 'Tools;Education', 'Entertainment;Brain Games', 'Racing', 'Educational;Pretend Play', 'Music', 'Music;Music & Video', 'Dating', 'Finance', 'Books & Reference;Education', 'Educational;Education', 'Strategy;Education', 'Productivity', 'Trivia', 'Arcade;Action & Adventure', 'Adventure;Action & Adventure', 'Business', 'Educational', 'Casual;Music & Video', 'Word', 'Arcade;Pretend Play', 'Lifestyle', 'Casual;Creativity', 'Entertainment;Music & Video', 'Video Players & Editors;Creativity', 'Trivia;Education', 'Parenting;Music & Video', 'Art & Design;Action & Adventure', 'Health & Fitness;Education', 'Card;Brain Games', 'Strategy', 'Board;Pretend Play', 'Comics;Creativity', 'Casual;Education', 'February 11, 2018', 'Events', 'Comics', 'Shopping', 'Parenting;Brain Games', 'Card;Action & Adventure', 'Casual;Action & Adventure', 'Puzzle;Brain Games', 'Puzzle', 'Communication;Creativity', 'Casual', 'Education;Action & Adventure', 'Photography', 'Casino', 'Tools', 'Lifestyle;Pretend Play', 'Sports;Action & Adventure', 'Sports', 'Entertainment;Action & Adventure', 'Personalization', 'Food & Drink', 'Role Playing', 'News & Magazines', 'Lifestyle;Education', 'Health & Fitness;Action & Adventure', 'Entertainment;Pretend Play', 'Communication', 'Role Playing;Education'}
# There are 120 unique genres in the dataframe

# %%
#more elegant way is to be aware of basic pandas methods and use them

#TODO use  method .unique() display all unique Generes in dataset
#TODO use  method .nunique() count all unique Generes in datasets

print(df["Genres"].nunique())
print(df["Genres"].unique())
# Out:
# 120
# ['Art & Design' 'Art & Design;Pretend Play' 'Art & Design;Creativity'
#  'Art & Design;Action & Adventure' 'Auto & Vehicles' 'Beauty'
#  'Books & Reference' 'Business' 'Comics' 'Comics;Creativity'
#  'Communication' 'Dating' 'Education;Education' 'Education'
#  'Education;Creativity' 'Education;Music & Video'
#  'Education;Action & Adventure' 'Education;Pretend Play'
#  'Education;Brain Games' 'Entertainment' 'Entertainment;Music & Video'
#  'Entertainment;Brain Games' 'Entertainment;Creativity' 'Events' 'Finance'
#  'Food & Drink' 'Health & Fitness' 'House & Home' 'Libraries & Demo'
#  'Lifestyle' 'Lifestyle;Pretend Play' 'Adventure;Action & Adventure'
#  'Arcade' 'Casual' 'Card' 'Casual;Pretend Play' 'Action' 'Strategy'
#  'Puzzle' 'Sports' 'Music' 'Word' 'Racing' 'Casual;Creativity'
#  'Casual;Action & Adventure' 'Simulation' 'Adventure' 'Board' 'Trivia'
#  'Role Playing' 'Simulation;Education' 'Action;Action & Adventure'
#  'Casual;Brain Games' 'Simulation;Action & Adventure'
#  'Educational;Creativity' 'Puzzle;Brain Games' 'Educational;Education'
#  'Card;Brain Games' 'Educational;Brain Games' 'Educational;Pretend Play'
#  'Entertainment;Education' 'Casual;Education' 'Music;Music & Video'
#  'Racing;Action & Adventure' 'Arcade;Pretend Play'
#  'Role Playing;Action & Adventure' 'Simulation;Pretend Play'
#  'Puzzle;Creativity' 'Sports;Action & Adventure'
#  'Educational;Action & Adventure' 'Arcade;Action & Adventure'
#  'Entertainment;Action & Adventure' 'Puzzle;Action & Adventure'
#  'Strategy;Action & Adventure' 'Music & Audio;Music & Video'
#  'Health & Fitness;Education' 'Adventure;Education' 'Board;Brain Games'
#  'Board;Action & Adventure' 'Board;Pretend Play' 'Casual;Music & Video'
#  'Role Playing;Pretend Play' 'Entertainment;Pretend Play'
#  'Video Players & Editors;Creativity' 'Card;Action & Adventure' 'Medical'
#  'Social' 'Shopping' 'Photography' 'Travel & Local'
#  'Travel & Local;Action & Adventure' 'Tools' 'Tools;Education'
#  'Personalization' 'Productivity' 'Parenting' 'Parenting;Music & Video'
#  'Parenting;Education' 'Parenting;Brain Games' 'Weather'
#  'Video Players & Editors' 'Video Players & Editors;Music & Video'
#  'News & Magazines' 'Maps & Navigation'
#  'Health & Fitness;Action & Adventure' 'Educational' 'Casino'
#  'Adventure;Brain Games' 'Trivia;Education' 'Lifestyle;Education'
#  'Books & Reference;Creativity' 'Books & Reference;Education'
#  'Puzzle;Education' 'Role Playing;Education' 'Role Playing;Brain Games'
#  'Strategy;Education' 'Racing;Pretend Play' 'Communication;Creativity'
#  'February 11, 2018' 'Strategy;Creativity']

# %% [markdown]
# # Conditions and filtering

# %%
#let's write a condition
filter = df.Genres == "Word"
print(filter)
df.Genres == "Word"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Genres, Length: 10841, dtype: bool
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Genres, Length: 10841, dtype: bool

# %%
#let's write or condition
(df.Genres == "Word") | (df.Genres == "Lifestyle")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840     True
# Name: Genres, Length: 10841, dtype: bool

# %%
#same result can be achieved from
df.Genres.isin(["Word", "Lifestyle"])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840     True
# Name: Genres, Length: 10841, dtype: bool

# %%
#let's write and condition
(df.Genres == "Word") & (df.Genres == "Lifestyle")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Genres, Length: 10841, dtype: bool

# %%
#let's select rows where condition is true
condition = (df.Genres == "Word") | (df.Genres == "Lifestyle")
df[condition]
# Out:
#                                                      App   Category  Rating  \
# 1562                          Dollhouse Decorating Games  LIFESTYLE     4.1
# 1563                                           metroZONE  LIFESTYLE     4.1
# 1564                              Easy Hair Style Design  LIFESTYLE     4.3
# 1566   Black Wallpaper, AMOLED, Dark Background: Darkify  LIFESTYLE     4.6
# 1567                        Girly Wallpapers Backgrounds  LIFESTYLE     4.4
# ...                                                  ...        ...     ...
# 10791                                  Winter Wonderland       GAME     4.0
# 10797                              Fuel Rewards® program  LIFESTYLE     4.6
# 10805                                      Scoreboard FR  LIFESTYLE     4.3
# 10808                                 lesparticuliers.fr  LIFESTYLE     NaN
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#       Reviews  Size     Installs  Type Price Content Rating     Genres  \
# 1562    18968   32M   5,000,000+  Free     0           Teen  Lifestyle
# 1563    47497   34M  10,000,000+  Free     0       Everyone  Lifestyle
# 1564      601  5.1M     100,000+  Free     0       Everyone  Lifestyle
# 1566    51357   80M   5,000,000+  Free     0       Everyone  Lifestyle
# 1567    13565  3.3M   1,000,000+  Free     0       Everyone  Lifestyle
# ...       ...   ...          ...   ...   ...            ...        ...
# 10791    1287   38M      50,000+  Free     0       Everyone       Word
# 10797   32433   46M   1,000,000+  Free     0       Everyone  Lifestyle
# 10805       3   15M         100+  Free     0       Everyone  Lifestyle
# 10808      96  1.0M      50,000+  Free     0       Everyone  Lifestyle
# 10840  398307   19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#             Last Updated         Current Ver         Android Ver
# 1562      April 26, 2018                 5.1          4.1 and up
# 1563        June 8, 2018          5.3.0.54.7          5.0 and up
# 1564   December 20, 2017                 1.0          2.3 and up
# 1566       July 31, 2018                 8.0          4.0 and up
# 1567      August 5, 2018                 2.5          4.0 and up
# ...                  ...                 ...                 ...
# 10791  December 18, 2013                 1.0          2.2 and up
# 10797      June 26, 2018               2.9.1          5.0 and up
# 10805     August 7, 2018                 2.1          4.2 and up
# 10808  November 25, 2014                 1.5          2.3 and up
# 10840      July 25, 2018  Varies with device  Varies with device
#
# [410 rows x 13 columns]

# %%
#let's select rows where condition is true
condition = (df.Genres == "Word") | (df.Genres == "Lifestyle")
df[~condition]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
#
#       Content Rating                     Genres        Last Updated  \
# 0           Everyone               Art & Design     January 7, 2018
# 1           Everyone  Art & Design;Pretend Play    January 15, 2018
# 2           Everyone               Art & Design      August 1, 2018
# 3               Teen               Art & Design        June 8, 2018
# 4           Everyone    Art & Design;Creativity       June 20, 2018
# ...              ...                        ...                 ...
# 10835       Everyone                   Business  September 29, 2016
# 10836       Everyone                  Education       July 25, 2017
# 10837       Everyone                  Education        July 6, 2018
# 10838       Everyone                    Medical    January 20, 2017
# 10839     Mature 17+          Books & Reference    January 19, 2015
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10835               1.1.5          4.0 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
#
# [10431 rows x 13 columns]

# %%
#TODO select data where Category is FAMILY and Genres is Education
#TODO we explored, how .isin() method is used. Explore method .isna() to find out which rows have nan values
#TODO sum, how many rows containing nan we have in the data

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
filter = ~(df.isna())
df[filter]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %% [markdown]
# # Joining and merging

# %%
df2 = {"Content Rating":['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+', 'Adults only 18+', 'Unrated', np.nan],
 "Restriction":["No", "No", "Yes", "Yes","Yes", "N/A", "N/A"]}
df2 = pd.DataFrame(df2)
df2.head()
# Out:
#     Content Rating Restriction
# 0         Everyone          No
# 1             Teen          No
# 2     Everyone 10+         Yes
# 3       Mature 17+         Yes
# 4  Adults only 18+         Yes

# %%
# Merge two DataFrames by a common column
print(len(df))
merged_df = pd.merge(df, df2, on='Content Rating')
print(len(merged_df))
print(merged_df[["Content Rating", "Restriction"]].isna().sum())
# Out:
# 10841
# 10841
# Content Rating    1
# Restriction       0
# dtype: int64

# %%
merged_df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# 4                             Paper flowers instructions  ART_AND_DESIGN
# ...                                                  ...             ...
# 10836                  DraftKings - Daily Fantasy Sports          SPORTS
# 10837                                        Manga Books          COMICS
# 10838                                Best CG Photography          FAMILY
# 10839                             DC Universe Online Map           TOOLS
# 10840            Life Made WI-Fi Touchscreen Photo Frame             1.9
#
#        Rating Reviews                Size    Installs  Type     Price  \
# 0         4.1     159                 19M     10,000+  Free         0
# 1         3.9     967                 14M    500,000+  Free         0
# 2         4.7   87510                8.7M  5,000,000+  Free         0
# 3         4.3     967                2.8M    100,000+  Free         0
# 4         4.4     167                5.6M     50,000+  Free         0
# ...       ...     ...                 ...         ...   ...       ...
# 10836     4.5   50017                 41M  1,000,000+  Free         0
# 10837     3.8    7326  Varies with device    500,000+  Free         0
# 10838     NaN       1                2.5M        500+  Free         0
# 10839     4.1    1186                6.4M     50,000+  Free         0
# 10840    19.0    3.0M              1,000+        Free     0  Everyone
#
#         Content Rating                     Genres       Last Updated  \
# 0             Everyone               Art & Design    January 7, 2018
# 1             Everyone  Art & Design;Pretend Play   January 15, 2018
# 2             Everyone               Art & Design     August 1, 2018
# 3             Everyone    Art & Design;Creativity      June 20, 2018
# 4             Everyone               Art & Design     March 26, 2017
# ...                ...                        ...                ...
# 10836  Adults only 18+                     Sports      July 24, 2018
# 10837  Adults only 18+                     Comics     August 3, 2018
# 10838          Unrated              Entertainment      June 24, 2015
# 10839          Unrated                      Tools  February 27, 2012
# 10840              NaN          February 11, 2018             1.0.19
#
#               Current Ver         Android Ver Restriction
# 0                   1.0.0        4.0.3 and up          No
# 1                   2.0.0        4.0.3 and up          No
# 2                   1.2.4        4.0.3 and up          No
# 3                     1.1          4.4 and up          No
# 4                     1.0          2.3 and up          No
# ...                   ...                 ...         ...
# 10836            3.21.324          4.4 and up         Yes
# 10837  Varies with device  Varies with device         Yes
# 10838                 5.2          3.0 and up         N/A
# 10839                 1.3        2.3.3 and up         N/A
# 10840          4.0 and up                 NaN         N/A
#
# [10841 rows x 14 columns]

# %%
merged_df[merged_df["Content Rating"].isna()]
# Out:
#                                            App Category  Rating Reviews  \
# 10840  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10840  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver Restriction
# 10840       1.0.19  4.0 and up         NaN         N/A

# %%
df2 = {"Content Rating":['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+', 'Adults only 18+', 'Unrated'],
 "Restriction":["No", "No", "Yes", "Yes","Yes", "N/A"]}
df2 = pd.DataFrame(df2)

# Merge with different types of joins (e.g., inner, outer, left, right)
merged_df = pd.merge(df, df2, on='Content Rating', how='inner')

print(len(df))
print(len(merged_df))
# Out:
# 10841
# 10840

# %%
pd.concat([df, df2], axis=0)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# ..                                                ...             ...     ...
# 1                                                 NaN             NaN     NaN
# 2                                                 NaN             NaN     NaN
# 3                                                 NaN             NaN     NaN
# 4                                                 NaN             NaN     NaN
# 5                                                 NaN             NaN     NaN
#
#    Reviews  Size     Installs  Type Price   Content Rating  \
# 0      159   19M      10,000+  Free     0         Everyone
# 1      967   14M     500,000+  Free     0         Everyone
# 2    87510  8.7M   5,000,000+  Free     0         Everyone
# 3   215644   25M  50,000,000+  Free     0             Teen
# 4      967  2.8M     100,000+  Free     0         Everyone
# ..     ...   ...          ...   ...   ...              ...
# 1      NaN   NaN          NaN   NaN   NaN             Teen
# 2      NaN   NaN          NaN   NaN   NaN     Everyone 10+
# 3      NaN   NaN          NaN   NaN   NaN       Mature 17+
# 4      NaN   NaN          NaN   NaN   NaN  Adults only 18+
# 5      NaN   NaN          NaN   NaN   NaN          Unrated
#
#                        Genres      Last Updated         Current Ver  \
# 0                Art & Design   January 7, 2018               1.0.0
# 1   Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                Art & Design    August 1, 2018               1.2.4
# 3                Art & Design      June 8, 2018  Varies with device
# 4     Art & Design;Creativity     June 20, 2018                 1.1
# ..                        ...               ...                 ...
# 1                         NaN               NaN                 NaN
# 2                         NaN               NaN                 NaN
# 3                         NaN               NaN                 NaN
# 4                         NaN               NaN                 NaN
# 5                         NaN               NaN                 NaN
#
#      Android Ver Restriction
# 0   4.0.3 and up         NaN
# 1   4.0.3 and up         NaN
# 2   4.0.3 and up         NaN
# 3     4.2 and up         NaN
# 4     4.4 and up         NaN
# ..           ...         ...
# 1            NaN          No
# 2            NaN         Yes
# 3            NaN         Yes
# 4            NaN         Yes
# 5            NaN         N/A
#
# [10847 rows x 14 columns]

# %%
pd.concat([df, df2], axis=1).head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
# 6     178   19M      50,000+  Free     0       Everyone
# 7   36815   29M   1,000,000+  Free     0       Everyone
# 8   13791   33M   1,000,000+  Free     0       Everyone
# 9     121  3.1M      10,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                 1.0
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#     Android Ver   Content Rating Restriction
# 0  4.0.3 and up         Everyone          No
# 1  4.0.3 and up             Teen          No
# 2  4.0.3 and up     Everyone 10+         Yes
# 3    4.2 and up       Mature 17+         Yes
# 4    4.4 and up  Adults only 18+         Yes
# 5    2.3 and up          Unrated         N/A
# 6  4.0.3 and up              NaN         NaN
# 7    4.2 and up              NaN         NaN
# 8    3.0 and up              NaN         NaN
# 9  4.0.3 and up              NaN         NaN

# %% [markdown]
# # Transforming columns

# %%
def multiply_twice(x):
    return x * 2

df['new_rating_var1'] = df['Rating'].apply(multiply_twice)
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver  new_rating_var1
# 0  4.0.3 and up              8.2
# 1  4.0.3 and up              7.8
# 2  4.0.3 and up              9.4
# 3    4.2 and up              9.0
# 4    4.4 and up              8.6

# %%
# Apply a lambda function to a column
# lambda is a way for defining the anonymous function
df['new_rating_var2'] = df['Rating'].apply(lambda x: x * 2)


# Using lambda with conditionals
df['rating_conditional'] = df['Rating'].apply(lambda x: x * 2 if x > 1 else x)

# %%
df[df.Rating <= 1].head(10)
# Out:
#                                    App       Category  Rating Reviews  Size  \
# 625            House party - live chat         DATING     1.0       1  9.2M
# 4127                 Speech Therapy: F         FAMILY     1.0       1   16M
# 5151                     Clarksburg AH        MEDICAL     1.0       1   28M
# 5978     Truck Driving Test Class 3 BC         FAMILY     1.0       1  2.0M
# 6319  BJ Bridge Standard American 2018           GAME     1.0       1  4.9M
# 6490                            MbH BM        MEDICAL     1.0       1  2.3M
# 7144                     CB Mobile Biz        FINANCE     1.0       3  8.4M
# 7383                    Thistletown CI   PRODUCTIVITY     1.0       1  6.6M
# 7427                    CJ DVD Rentals  COMMUNICATION     1.0       5   13M
# 7806                       CR Magazine       BUSINESS     1.0       1  7.8M
#
#      Installs  Type  Price Content Rating         Genres       Last Updated  \
# 625       10+  Free      0     Mature 17+         Dating      July 31, 2018
# 4127      10+  Paid  $2.99       Everyone      Education    October 7, 2016
# 5151      50+  Free      0       Everyone        Medical        May 1, 2017
# 5978      50+  Paid  $1.49       Everyone      Education      April 9, 2012
# 6319   1,000+  Free      0       Everyone           Card       May 21, 2018
# 6490     100+  Free      0       Everyone        Medical  December 14, 2016
# 7144     500+  Free      0       Everyone        Finance  February 22, 2016
# 7383     100+  Free      0       Everyone   Productivity     March 15, 2018
# 7427     100+  Free      0       Everyone  Communication    October 6, 2017
# 7806     100+  Free      0       Everyone       Business      July 23, 2014
#
#       Current Ver   Android Ver  new_rating_var1  new_rating_var2  \
# 625          3.52  4.0.3 and up              2.0              2.0
# 4127          1.0  2.3.3 and up              2.0              2.0
# 5151  300000.0.81  4.0.3 and up              2.0              2.0
# 5978          1.0    2.1 and up              2.0              2.0
# 6319     6.2-sayc    4.0 and up              2.0              2.0
# 6490        1.1.3    4.3 and up              2.0              2.0
# 7144     4.4.1255    4.0 and up              2.0              2.0
# 7383         41.9    4.1 and up              2.0              2.0
# 7427          1.0    4.1 and up              2.0              2.0
# 7806        2.4.2  2.3.3 and up              2.0              2.0
#
#       rating_conditional
# 625                  1.0
# 4127                 1.0
# 5151                 1.0
# 5978                 1.0
# 6319                 1.0
# 6490                 1.0
# 7144                 1.0
# 7383                 1.0
# 7427                 1.0
# 7806                 1.0

# %% [markdown]
# # Aggregating dataframe

# %%
# Calculate mean, sum, and other aggregate functions
mean_value = df['Rating'].mean()
sum_value = df['Rating'].sum()

print(mean_value, sum_value)

# Group by a column and apply aggregation functions
grouped_df = df.groupby('Content Rating')['Rating'].agg(['mean', 'sum', 'count'])
grouped_df
# Out:
# 4.193338315362443 39279.0
#                      mean      sum  count
# Content Rating
# Adults only 18+  4.300000     12.9      3
# Everyone         4.186375  31062.9   7420
# Everyone 10+     4.257179   1690.1    397
# Mature 17+       4.123427   1900.9    461
# Teen             4.233487   4589.1   1084
# Unrated          4.100000      4.1      1

# %%
# TODO use as_index =  False parameter in group by function to not use Content Rating as index
# perform the grouping by multiple columns e.g. Content Rating and Type

# %%
grouped_df = df.groupby(['Content Rating'], as_index = False)['Rating'].agg(['mean', 'sum', 'count'])
grouped_df
# Out:
#                      mean      sum  count
# Content Rating
# Adults only 18+  4.300000     12.9      3
# Everyone         4.186375  31062.9   7420
# Everyone 10+     4.257179   1690.1    397
# Mature 17+       4.123427   1900.9    461
# Teen             4.233487   4589.1   1084
# Unrated          4.100000      4.1      1

# %%
grouped_df.reset_index()
# Out:
#     Content Rating      mean      sum  count
# 0  Adults only 18+  4.300000     12.9      3
# 1         Everyone  4.186375  31062.9   7420
# 2     Everyone 10+  4.257179   1690.1    397
# 3       Mature 17+  4.123427   1900.9    461
# 4             Teen  4.233487   4589.1   1084
# 5          Unrated  4.100000      4.1      1

# %%
# Pivot table for aggregation
pivot_table = df.pivot_table(index='Content Rating', columns='Type', values='Price', aggfunc='sum')
pivot_table
# Out:
# Type                                                          Free  \
# Content Rating
# Adults only 18+                                                000
# Everyone         0000000000000000000000000000000000000000000000...
# Everyone 10+     0000000000000000000000000000000000000000000000...
# Mature 17+       0000000000000000000000000000000000000000000000...
# Teen             0000000000000000000000000000000000000000000000...
# Unrated                                                         00
#
# Type                                                          Paid
# Content Rating
# Adults only 18+                                                NaN
# Everyone         $4.99$4.99$4.99$4.99$3.99$6.99$2.99$3.99$5.99$...
# Everyone 10+     $1.99$6.99$2.99$10.00$9.99$10.00$17.99$6.99$2....
# Mature 17+       $3.99$7.99$3.99$2.99$11.99$11.99$0.99$1.99$3.9...
# Teen             $1.49$3.99$4.99$6.99$9.99$2.99$1.99$4.99$0.99$...
# Unrated                                                        NaN

# %%
#Price should be float!
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   App                 10841 non-null  object
#  1   Category            10841 non-null  object
#  2   Rating              9367 non-null   float64
#  3   Reviews             10841 non-null  object
#  4   Size                10841 non-null  object
#  5   Installs            10841 non-null  object
#  6   Type                10840 non-null  object
#  7   Price               10841 non-null  object
#  8   Content Rating      10840 non-null  object
#  9   Genres              10841 non-null  object
#  10  Last Updated        10841 non-null  object
#  11  Current Ver         10833 non-null  object
#  12  Android Ver         10838 non-null  object
#  13  new_rating_var1     9367 non-null   float64
#  14  new_rating_var2     9367 non-null   float64
#  15  rating_conditional  9367 non-null   float64
# dtypes: float64(4), object(12)
# memory usage: 1.3+ MB

# %%
df.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', 'Everyone', '$1.20', '$1.04'], dtype=object)

# %%
#This is messy,  first lets get rid of dollar sign
df["Price"] = df["Price"].str.replace('$', '')
# Out:
# <ipython-input-68-7e67b2b13bf4>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Price"] = df["Price"].str.replace('$', '')

# %%
df.Price.unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        'Everyone', '1.20', '1.04'], dtype=object)

# %%
df[df.Price=="Everyone"]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver  new_rating_var1  new_rating_var2  \
# 10472       1.0.19  4.0 and up         NaN             38.0             38.0
#
#        rating_conditional
# 10472                38.0

# %%
#The roow suggest its free
df["Price"] = df["Price"].str.replace('Everyone', '0')

# %%
#change data types using function .astype()
convert_dict = {'Price': float}
df = df.astype(convert_dict, )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   App                 10841 non-null  object
#  1   Category            10841 non-null  object
#  2   Rating              9367 non-null   float64
#  3   Reviews             10841 non-null  object
#  4   Size                10841 non-null  object
#  5   Installs            10841 non-null  object
#  6   Type                10840 non-null  object
#  7   Price               10841 non-null  float64
#  8   Content Rating      10840 non-null  object
#  9   Genres              10841 non-null  object
#  10  Last Updated        10841 non-null  object
#  11  Current Ver         10833 non-null  object
#  12  Android Ver         10838 non-null  object
#  13  new_rating_var1     9367 non-null   float64
#  14  new_rating_var2     9367 non-null   float64
#  15  rating_conditional  9367 non-null   float64
# dtypes: float64(5), object(11)
# memory usage: 1.3+ MB

# %%
# Pivot table for aggregation
pivot_table = df.pivot_table(index='Content Rating', columns='Type', values='Price', aggfunc='sum')
pivot_table
# Out:
# Type             Free      Paid
# Content Rating
# Adults only 18+   0.0       NaN
# Everyone          0.0  10205.60
# Everyone 10+      0.0    156.69
# Mature 17+        0.0    118.10
# Teen              0.0    656.28
# Unrated           0.0       NaN

# %%
#TODO use pandas .melt() to unpivot table, use documentation to find out, which arguments you need to provide
#TODO export pivot_table to exel using to_excel() function
#TODO use reset_index to change Type in pivot_table from index to column

# %%
import pandas as pd

# Create a sample DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
        'Age': [25, 30, 35, 22, 28]}
df = pd.DataFrame(data)

# Iterate through the DataFrame using iterrows()
for index, row in df.iterrows():
    print(f"Index: {index}, Name: {row['Name']}, Age: {row['Age']}")
# Out:
# Index: 0, Name: Alice, Age: 25
# Index: 1, Name: Bob, Age: 30
# Index: 2, Name: Charlie, Age: 35
# Index: 3, Name: David, Age: 22
# Index: 4, Name: Emily, Age: 28
