# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
import statsmodels.api as sm

# Load the dataset
data = sm.datasets.get_rdataset('AirPassengers').data
data['time'] = pd.date_range(start='1949-01', periods=len(data), freq='M')
data.set_index('time', inplace=True)

# Plot the dataset
plt.figure(figsize=(10, 6))
plt.plot(data['value'])
plt.title('Airline Passengers Over Time')
plt.show()

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data['value'].values.reshape(-1, 1))

# %%
# Function to create the supervised learning problem
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 3
X, y = create_dataset(data_scaled, look_back)

# Reshape input to be [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Train the model
model.fit(X, y, epochs=100, batch_size=1, verbose=2)

# Predictions
predictions = model.predict(X)
# Out:
# Epoch 1/100
# 140/140 - 9s - loss: 0.0400 - 9s/epoch - 65ms/step
# Epoch 2/100
# 140/140 - 1s - loss: 0.0126 - 882ms/epoch - 6ms/step
# Epoch 3/100
# 140/140 - 1s - loss: 0.0119 - 970ms/epoch - 7ms/step
# Epoch 4/100
# 140/140 - 1s - loss: 0.0108 - 839ms/epoch - 6ms/step
# Epoch 5/100
# 140/140 - 1s - loss: 0.0101 - 873ms/epoch - 6ms/step
# Epoch 6/100
# 140/140 - 1s - loss: 0.0095 - 826ms/epoch - 6ms/step
# Epoch 7/100
# 140/140 - 1s - loss: 0.0095 - 759ms/epoch - 5ms/step
# Epoch 8/100
# 140/140 - 1s - loss: 0.0092 - 823ms/epoch - 6ms/step
# Epoch 9/100
# 140/140 - 1s - loss: 0.0093 - 799ms/epoch - 6ms/step
# Epoch 10/100
# 140/140 - 2s - loss: 0.0088 - 2s/epoch - 11ms/step
# Epoch 11/100
# 140/140 - 1s - loss: 0.0087 - 1s/epoch - 8ms/step
# Epoch 12/100
# 140/140 - 1s - loss: 0.0080 - 1s/epoch - 11ms/step
# Epoch 13/100
# 140/140 - 1s - loss: 0.0079 - 940ms/epoch - 7ms/step
# Epoch 14/100
# 140/140 - 1s - loss: 0.0074 - 866ms/epoch - 6ms/step
# Epoch 15/100
# 140/140 - 1s - loss: 0.0073 - 1s/epoch - 9ms/step
# Epoch 16/100
# 140/140 - 2s - loss: 0.0068 - 2s/epoch - 14ms/step
# Epoch 17/100
# 140/140 - 1s - loss: 0.0063 - 1s/epoch - 8ms/step
# Epoch 18/100
# 140/140 - 2s - loss: 0.0068 - 2s/epoch - 12ms/step
# Epoch 19/100
# 140/140 - 1s - loss: 0.0056 - 944ms/epoch - 7ms/step
# Epoch 20/100
# 140/140 - 2s - loss: 0.0059 - 2s/epoch - 13ms/step
# Epoch 21/100
# 140/140 - 2s - loss: 0.0057 - 2s/epoch - 14ms/step
# Epoch 22/100
# 140/140 - 1s - loss: 0.0047 - 852ms/epoch - 6ms/step
# Epoch 23/100
# 140/140 - 1s - loss: 0.0049 - 766ms/epoch - 5ms/step
# Epoch 24/100
# 140/140 - 1s - loss: 0.0045 - 701ms/epoch - 5ms/step
# Epoch 25/100
# 140/140 - 1s - loss: 0.0042 - 801ms/epoch - 6ms/step
# Epoch 26/100
# 140/140 - 1s - loss: 0.0044 - 716ms/epoch - 5ms/step
# Epoch 27/100
# 140/140 - 1s - loss: 0.0043 - 754ms/epoch - 5ms/step
# Epoch 28/100
# 140/140 - 1s - loss: 0.0042 - 724ms/epoch - 5ms/step
# Epoch 29/100
# 140/140 - 1s - loss: 0.0042 - 803ms/epoch - 6ms/step
# Epoch 30/100
# 140/140 - 1s - loss: 0.0038 - 673ms/epoch - 5ms/step
# Epoch 31/100
# 140/140 - 1s - loss: 0.0039 - 696ms/epoch - 5ms/step
# Epoch 32/100
# 140/140 - 1s - loss: 0.0038 - 670ms/epoch - 5ms/step
# Epoch 33/100
# 140/140 - 1s - loss: 0.0037 - 682ms/epoch - 5ms/step
# Epoch 34/100
# 140/140 - 1s - loss: 0.0040 - 979ms/epoch - 7ms/step
# Epoch 35/100
# 140/140 - 1s - loss: 0.0037 - 913ms/epoch - 7ms/step
# Epoch 36/100
# 140/140 - 1s - loss: 0.0036 - 1s/epoch - 8ms/step
# Epoch 37/100
# 140/140 - 1s - loss: 0.0038 - 1s/epoch - 9ms/step
# Epoch 38/100
# 140/140 - 2s - loss: 0.0035 - 2s/epoch - 12ms/step
# Epoch 39/100
# 140/140 - 1s - loss: 0.0036 - 1s/epoch - 10ms/step
# Epoch 40/100
# 140/140 - 1s - loss: 0.0036 - 1s/epoch - 10ms/step
# Epoch 41/100
# 140/140 - 1s - loss: 0.0035 - 1s/epoch - 9ms/step
# Epoch 42/100
# 140/140 - 1s - loss: 0.0040 - 1s/epoch - 8ms/step
# Epoch 43/100
# 140/140 - 1s - loss: 0.0039 - 1s/epoch - 8ms/step
# Epoch 44/100
# 140/140 - 1s - loss: 0.0036 - 707ms/epoch - 5ms/step
# Epoch 45/100
# 140/140 - 1s - loss: 0.0034 - 733ms/epoch - 5ms/step
# Epoch 46/100
# 140/140 - 1s - loss: 0.0038 - 738ms/epoch - 5ms/step
# Epoch 47/100
# 140/140 - 1s - loss: 0.0037 - 803ms/epoch - 6ms/step
# Epoch 48/100
# 140/140 - 1s - loss: 0.0031 - 788ms/epoch - 6ms/step
# Epoch 49/100
# 140/140 - 1s - loss: 0.0039 - 810ms/epoch - 6ms/step
# Epoch 50/100
# 140/140 - 1s - loss: 0.0037 - 722ms/epoch - 5ms/step
# Epoch 51/100
# 140/140 - 1s - loss: 0.0035 - 956ms/epoch - 7ms/step
# Epoch 52/100
# 140/140 - 1s - loss: 0.0036 - 725ms/epoch - 5ms/step
# Epoch 53/100
# 140/140 - 1s - loss: 0.0036 - 725ms/epoch - 5ms/step
# Epoch 54/100
# 140/140 - 1s - loss: 0.0035 - 700ms/epoch - 5ms/step
# Epoch 55/100
# 140/140 - 1s - loss: 0.0038 - 691ms/epoch - 5ms/step
# Epoch 56/100
# 140/140 - 1s - loss: 0.0035 - 740ms/epoch - 5ms/step
# Epoch 57/100
# 140/140 - 1s - loss: 0.0035 - 721ms/epoch - 5ms/step
# Epoch 58/100
# 140/140 - 1s - loss: 0.0034 - 719ms/epoch - 5ms/step
# Epoch 59/100
# 140/140 - 1s - loss: 0.0039 - 728ms/epoch - 5ms/step
# Epoch 60/100
# 140/140 - 1s - loss: 0.0038 - 724ms/epoch - 5ms/step
# Epoch 61/100
# 140/140 - 1s - loss: 0.0036 - 737ms/epoch - 5ms/step
# Epoch 62/100
# 140/140 - 1s - loss: 0.0035 - 708ms/epoch - 5ms/step
# Epoch 63/100
# 140/140 - 1s - loss: 0.0035 - 692ms/epoch - 5ms/step
# Epoch 64/100
# 140/140 - 1s - loss: 0.0038 - 683ms/epoch - 5ms/step
# Epoch 65/100
# 140/140 - 1s - loss: 0.0035 - 669ms/epoch - 5ms/step
# Epoch 66/100
# 140/140 - 1s - loss: 0.0036 - 1s/epoch - 8ms/step
# Epoch 67/100
# 140/140 - 1s - loss: 0.0036 - 1s/epoch - 10ms/step
# Epoch 68/100
# 140/140 - 1s - loss: 0.0035 - 785ms/epoch - 6ms/step
# Epoch 69/100
# 140/140 - 1s - loss: 0.0039 - 755ms/epoch - 5ms/step
# Epoch 70/100
# 140/140 - 1s - loss: 0.0035 - 628ms/epoch - 4ms/step
# Epoch 71/100
# 140/140 - 1s - loss: 0.0034 - 706ms/epoch - 5ms/step
# Epoch 72/100
# 140/140 - 1s - loss: 0.0034 - 692ms/epoch - 5ms/step
# Epoch 73/100
# 140/140 - 1s - loss: 0.0035 - 804ms/epoch - 6ms/step
# Epoch 74/100
# 140/140 - 1s - loss: 0.0033 - 698ms/epoch - 5ms/step
# Epoch 75/100
# 140/140 - 1s - loss: 0.0036 - 765ms/epoch - 5ms/step
# Epoch 76/100
# 140/140 - 1s - loss: 0.0035 - 667ms/epoch - 5ms/step
# Epoch 77/100
# 140/140 - 1s - loss: 0.0035 - 705ms/epoch - 5ms/step
# Epoch 78/100
# 140/140 - 1s - loss: 0.0036 - 702ms/epoch - 5ms/step
# Epoch 79/100
# 140/140 - 1s - loss: 0.0035 - 942ms/epoch - 7ms/step
# Epoch 80/100
# 140/140 - 1s - loss: 0.0035 - 780ms/epoch - 6ms/step
# Epoch 81/100
# 140/140 - 1s - loss: 0.0035 - 660ms/epoch - 5ms/step
# Epoch 82/100
# 140/140 - 1s - loss: 0.0034 - 683ms/epoch - 5ms/step
# Epoch 83/100
# 140/140 - 1s - loss: 0.0038 - 665ms/epoch - 5ms/step
# Epoch 84/100
# 140/140 - 1s - loss: 0.0036 - 724ms/epoch - 5ms/step
# Epoch 85/100
# 140/140 - 1s - loss: 0.0036 - 705ms/epoch - 5ms/step
# Epoch 86/100
# 140/140 - 1s - loss: 0.0035 - 717ms/epoch - 5ms/step
# Epoch 87/100
# 140/140 - 1s - loss: 0.0034 - 681ms/epoch - 5ms/step
# Epoch 88/100
# 140/140 - 1s - loss: 0.0034 - 624ms/epoch - 4ms/step
# Epoch 89/100
# 140/140 - 1s - loss: 0.0033 - 679ms/epoch - 5ms/step
# Epoch 90/100
# 140/140 - 1s - loss: 0.0034 - 652ms/epoch - 5ms/step
# Epoch 91/100
# 140/140 - 1s - loss: 0.0035 - 636ms/epoch - 5ms/step
# Epoch 92/100
# 140/140 - 1s - loss: 0.0035 - 651ms/epoch - 5ms/step
# Epoch 93/100
# 140/140 - 1s - loss: 0.0034 - 668ms/epoch - 5ms/step
# Epoch 94/100
# 140/140 - 1s - loss: 0.0036 - 656ms/epoch - 5ms/step
# Epoch 95/100
# 140/140 - 1s - loss: 0.0035 - 675ms/epoch - 5ms/step
# Epoch 96/100
# 140/140 - 1s - loss: 0.0035 - 705ms/epoch - 5ms/step
# Epoch 97/100
# 140/140 - 1s - loss: 0.0034 - 731ms/epoch - 5ms/step
# Epoch 98/100
# 140/140 - 1s - loss: 0.0036 - 674ms/epoch - 5ms/step
# Epoch 99/100
# 140/140 - 1s - loss: 0.0035 - 692ms/epoch - 5ms/step
# Epoch 100/100
# 140/140 - 1s - loss: 0.0034 - 657ms/epoch - 5ms/step
# 5/5 [==============================] - 1s 4ms/step

# %%
# Inverse transformation for plotting
predictions = scaler.inverse_transform(predictions)

# Plotting the actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(data.index[look_back:len(predictions)+look_back], data['value'][look_back:len(predictions)+look_back])
plt.plot(data.index[look_back:len(predictions)+look_back], predictions, linestyle='--')
plt.title('Actual vs Predicted Passengers')
plt.legend(['Actual', 'Predicted'])
plt.show()
