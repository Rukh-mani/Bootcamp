# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-485bcb7c-f3c5-44cb-9cea-b0008dd6b116" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-485bcb7c-f3c5-44cb-9cea-b0008dd6b116">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Task 0 open data/titanic.csv
df = pd.read_csv('titanic.csv', engine = "python")
#df = pd.read_csv("https://raw.githubusercontent.com/CBP-DS/ds_intensive_course/main/data/titanic.csv?token=GHSAT0AAAAAACJTPLIL5TGN4SIHQ6VARBWOZKDLMNA")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Task 1 how many passangers are in the data?
print(df.PassengerId.nunique())
print(len(df.PassengerId.unique()))
# Out:
# 891
# 891

# %%
df.Name.str[0]
# Out:
# 0      B
# 1      C
# 2      H
# 3      F
# 4      A
#       ..
# 886    M
# 887    G
# 888    J
# 889    B
# 890    D
# Name: Name, Length: 891, dtype: object

# %%
#Task 2 How many distinct Surnames can you see in the data?

splitted_names = df.Name.str.split(",")
splitted_names
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
splitted_names = splitted_names.str[0]
splitted_names
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
print(splitted_names.nunique())
# Out:
# 667

# %%
#Task 3 sum Fare per A) location of Embarked B) Locatio of Embarked and Sex
#result should be dataframe

gr = df.groupby(["Embarked"], as_index = False).Fare.sum()
print(gr, "\n", type(gr))
# Out:
#   Embarked        Fare
# 0        C  10072.2962
# 1        Q   1022.2543
# 2        S  17439.3988
#  <class 'pandas.core.frame.DataFrame'>

# %%
gr = df.groupby(["Embarked"])["Fare"].sum()
print(gr, "\n", type(gr))
# Out:
# Embarked
# C    10072.2962
# Q     1022.2543
# S    17439.3988
# Name: Fare, dtype: float64
#  <class 'pandas.core.series.Series'>

# %%
gr = df.groupby(["Embarked", "Sex"], as_index = False).Fare.sum()
print(gr, "\n", type(gr))
# Out:
#   Embarked     Sex       Fare
# 0        C  female  5487.3958
# 1        C    male  4584.9004
# 2        Q  female   454.8585
# 3        Q    male   567.3958
# 4        S  female  7864.4085
# 5        S    male  9574.9903
#  <class 'pandas.core.frame.DataFrame'>

# %%
gr = df.groupby(["Embarked", "Sex"], as_index = False)["Fare", "PassengerId"].sum()
print(gr, "\n", type(gr))
# Out:
#   Embarked     Sex       Fare  PassengerId
# 0        C  female  5487.3958        31924
# 1        C    male  4584.9004        42896
# 2        Q  female   454.8585        13469
# 3        Q    male   567.3958        18709
# 4        S  female  7864.4085        89058
# 5        S    male  9574.9903       200438
#  <class 'pandas.core.frame.DataFrame'>
# <ipython-input-45-07e09025ed9f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   gr = df.groupby(["Embarked", "Sex"], as_index = False)["Fare", "PassengerId"].sum()

# %%
#Task 4 How wold you drop all rows that contain none? How about dropping rows that have none in Cabin?
print(len(df))
no_nan = df.dropna()
print(len(no_nan))
# Out:
# 891
# 183

# %%
print(len(df))
no_nan_cabin = df.dropna(subset = ["Cabin"])
print(len(no_nan_cabin))
# Out:
# 891
# 204

# %%
#Task 5 Use columns SibSp and Parch to form binary attribute has_family (use max or addition of two columns)

# %%
df["SibSp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
df["Parch"].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
df["has_family"] = df["SibSp"].values + df["Parch"].values

# %%
filter = df["has_family"]>1
df[filter]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# ..           ...       ...     ...
# 863          864         0       3
# 869          870         1       3
# 871          872         1       1
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[filter, "has_family"] = 1
print(df["has_family"].unique())
# Out:
# [1 0]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  has_family
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# ...

# %%
#Task 6 drop column has family
df = df.drop("has_family", axis = 1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Task 7 Use conditions approach to form has_family attriubte

filter = (df["SibSp"]>0) | (df["Parch"]>0)
df["has_family"] = 0
df.loc[filter, "has_family"] = 1

# %%
columns_to_keep = df.columns[2:7]

# %%
df[df.columns[:-1]]

# %%
df = df[columns_to_keep]

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp
# 0        1
# 1        1
# ...

# %%
#Task 8 What is the overall age average? What is the age average for women? And for men?
print(df["Age"].mean())
df.groupby(["Sex"])["Age"].mean()
# Out:
# 29.69911764705882
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
#Task 9 how many passerngers traveled on their own (alone)?

all_passengers = df['PassengerId'].nunique()
print(all_passengers)
hasfamily_passengers = df["has_family"].sum()
print(hasfamily_passengers)


alone = all_passengers - hasfamily_passengers
print(alone)
# Out:
# 891
# 354
# 537

# %%
filter = df["has_family"] == 0
df[filter]["PassengerId"].nunique()
# Out:
# 537

# %%
df["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df["different fare"] = 239240

# %%
df["different fare"]
# Out:
# 0      239240
# 1      239240
# 2      239240
# 3      239240
# 4      239240
#         ...
# 886    239240
# 887    239240
# 888    239240
# 889    239240
# 890    239240
# Name: different fare, Length: 891, dtype: int64

# %%
filter = df["has_family"] <1
filter
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: has_family, Length: 891, dtype: bool

# %%
print("This is the number of loners:", filter.sum())
# Out:
# This is the number of loners: 537

# %%
df = df.drop_duplicates()

# %%
#Task 10 is there any effect of class passengers traveled in and survival rate?
df["Pclass"].unique()

df.groupby(["Pclass"])["Cabin"].agg(Nunique='nunique', Count='count')
# Out:
#         Nunique  Count
# Pclass
# 1           133    176
# 2             7     16
# 3             7     12

# %%
df_filled = df.copy()
df_filled["Cabin"] = df_filled["Cabin"].fillna("unknown")
df_filled.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare    Cabin Embarked  has_family  different fare
# 0      0  A/5 21171   7.2500  unknown        S           1          239240
# 1      0   PC 17599  71.2833      C85        C           1          239240

# %%
df.groupby(["Pclass"])["Survived"].agg(Count='count', Sum='sum')
# Out:
#         Count  Sum
# Pclass
# 1         216  136
# 2         184   87
# 3         491  119

# %%
_ = df.groupby(["Pclass"])["Survived"].agg(Count='count', Sum='sum')
_["ratio"] = _["Sum"]/_["Count"]
_
# Out:
#         Count  Sum     ratio
# Pclass
# 1         216  136  0.629630
# 2         184   87  0.472826
# 3         491  119  0.242363

# %%
#Task 11 Do missing cabin values have something incommon with Pclass?
df_filled.groupby(["Pclass"])["Cabin"].agg(Nunique='nunique', Count='count')
# Out:
#         Nunique  Count
# Pclass
# 1           134    216
# 2             8    184
# 3             8    491

# %%
#Task 12 Create new column family name, count members of the family in data
df["family_name"] = df["Name"].str.split(",").str[0]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby(["family_name"])["PassengerId"].count()
# Out:
# family_name
# Abbing           1
# Abbott           2
# Abelson          2
# Adahl            1
# Adams            1
#                 ..
# de Mulder        1
# de Pelsmaeker    1
# del Carlo        1
# van Billiard     1
# van Melkebeke    1
# Name: PassengerId, Length: 667, dtype: int64

# %%
mapping = df['family_name'].value_counts()
print(mapping)
# Out:
# Andersson    9
# Sage         7
# Panula       6
# Skoog        6
# Carter       6
#             ..
# Hanna        1
# Lewy         1
# Mineff       1
# Haas         1
# Dooley       1
# Name: family_name, Length: 667, dtype: int64

# %%
_ = mapping.to_frame()
_ = _.reset_index()
_.columns = ["family_name", "freq"]
_
# Out:
#     family_name  freq
# 0     Andersson     9
# 1          Sage     7
# 2        Panula     6
# 3         Skoog     6
# 4        Carter     6
# ..          ...   ...
# 662       Hanna     1
# 663        Lewy     1
# 664      Mineff     1
# 665        Haas     1
# 666      Dooley     1
#
# [667 rows x 2 columns]

# %%
pd.merge(df, _, on = "family_name", how = "inner")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1            478         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 886          884         0       2
# 887          885         0       3
# 888          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1                            Braund, Mr. Lewis Richard    male  29.0      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3                               Heikkinen, Miss. Laina  female  26.0      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["family_name_freq"] = df['family_name'].map(mapping)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  has_family  \
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# ...

# %%
df["family_size"] = df.family_name_freq.values

# %%
df.loc[((df.has_family == 0)&(df.family_name_freq > 1)), "family_size"] = 1

df.groupby(["family_name", "family_size"])["PassengerId"].count()
# Out:
# family_name    family_size
# Abbing         1              1
# Abbott         2              2
# Abelson        2              2
# Adahl          1              1
# Adams          1              1
#                              ..
# de Mulder      1              1
# de Pelsmaeker  1              1
# del Carlo      1              1
# van Billiard   1              1
# van Melkebeke  1              1
# Name: PassengerId, Length: 689, dtype: int64

# %%
#Task 13 group Fare by 3 thresholds so you have category cheap fare, regular fare, expensive fare

# %%
#Task 14 form an empty dataset, append counts in fare category to it

# %%
empty_df = pd.DataFrame({})
empty_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Task 15 rename column PassengerId in appended dataframe to Passenger Count
